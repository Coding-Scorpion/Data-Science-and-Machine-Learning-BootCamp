# %% [markdown]
# # Lecture 5
#
#  Fall 2023
#
# A demonstration of advanced `pandas` syntax to accompany Lecture 5.

# %%
import numpy as np
import pandas as pd

# %%
field_names = ['State', 'Sex', 'Year', 'Name', 'Count']

babynames = pd.read_csv('H:/Machine Learning/babynamesbystate/STATE.CA.TXT', header=None, names=field_names)

data = babynames.copy()

data.head(2)
# Out:
#   State Sex  Year   Name  Count
# 0    CA   F  1910   Mary    295
# 1    CA   F  1910  Helen    239

# %% [markdown]
# ## Pivot Tables

# %% [markdown]
# ### `Groupby` with multiple columns

# %% [markdown]
# We want to build a table showing the total number of babies born of each sex in each year. One way is to `groupby` using both columns of interest:

# %%
# Find total count of baby names for both female and Male for each year

s = data.groupby(["Year","Sex"])["Count"].sum()

s.to_frame()
# Out:
#            Count
# Year Sex
# 1910 F      5950
#      M      3213
# 1911 F      6602
#      M      3381
# 1912 F      9804
# ...          ...
# 2020 M    189119
# 2021 F    173913
#      M    188669
# 2022 F    172454
#      M    187569
#
# [226 rows x 1 columns]

# %% [markdown]
# ### `pivot_table`

# %%
# Find total count of baby names for both female and Male for each year using Pivot table

piv_table = pd.pivot_table(data, index='Year', columns='Sex', values='Count', aggfunc='sum')
piv_table
# Out:
# Sex        F       M
# Year
# 1910    5950    3213
# 1911    6602    3381
# 1912    9804    8142
# 1913   11860   10234
# 1914   13815   13111
# ...      ...     ...
# 2018  189208  206228
# 2019  184228  202768
# 2020  173763  189119
# 2021  173913  188669
# 2022  172454  187569
#
# [113 rows x 2 columns]

# %% [markdown]
# ![pivot_picture.png](attachment:pivot_picture.png)

# %% [markdown]
# ### `pivot_table` with Multiple values

# %%
# Form a pivot table as describr in Lecture Slides

multi_pivot_vals = data.pivot_table(index = "Year", columns = "Sex", 
                                    values = ["Count", "Name"],aggfunc = np.max)

multi_pivot_vals
# Out:
# C:\Users\Usman\AppData\Local\Temp\ipykernel_30444\2654753712.py:3: FutureWarning: The provided callable <function max at 0x000001B85F3F7BA0> is currently using DataFrameGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   multi_pivot_vals = data.pivot_table(index = "Year", columns = "Sex",
#      Count          Name
# Sex      F     M       F        M
# Year
# 1910   295   237  Yvonne  William
# 1911   390   214   Zelma   Willis
# 1912   534   501  Yvonne  Woodrow
# 1913   584   614   Zelma   Yoshio
# 1914   773   769   Zelma   Yoshio
# ...    ...   ...     ...      ...
# 2018  2751  2572    Zyra     Zyon
# 2019  2608  2681    Zyra     Zyon
# 2020  2353  2630   Zyrah     Zyon
# 2021  2402  2613    Zyra    Zyrus
# 2022  2178  2610    Zyra     Zyon
#
# [113 rows x 4 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## Join Tables
#
# What if we want to know the popularity of presidential candidates' first names in California in 2022? What can we do?

# %%
elections = pd.read_csv("H:\Machine Learning\Excel files\elections 1.csv")
elections.head()
# Out:
#    Year          Candidate                  Party  Popular vote Result  \
# 0  1824     Andrew Jackson  Democratic-Republican        151271   loss
# 1  1824  John Quincy Adams  Democratic-Republican        113142    win
# 2  1828     Andrew Jackson             Democratic        642806    win
# 3  1828  John Quincy Adams    National Republican        500897   loss
# 4  1832     Andrew Jackson             Democratic        702735    win
#
#            %
# 0  57.210122
# 1  42.789878
# 2  56.203927
# 3  43.796073
# 4  54.574789

# %%
field_names = ['State', 'Sex', 'Year', 'Name', 'Count']

baby = pd.read_csv('H:/Machine Learning/babynamesbystate/STATE.CA.TXT', header=None, names=field_names)

baby.head()
# Out:
#   State Sex  Year      Name  Count
# 0    CA   F  1910      Mary    295
# 1    CA   F  1910     Helen    239
# 2    CA   F  1910   Dorothy    220
# 3    CA   F  1910  Margaret    163
# 4    CA   F  1910   Frances    134

# %%
# Collect baby names for 2022
baby_names = baby[baby["Year"] == 2022]
baby_names.head()
# Out:
#        State Sex  Year    Name  Count
# 235835    CA   F  2022  Olivia   2178
# 235836    CA   F  2022    Emma   2080
# 235837    CA   F  2022  Camila   2046
# 235838    CA   F  2022     Mia   1882
# 235839    CA   F  2022  Sophia   1762

# %%
# Use split the candidate names in elections dataframe
elections["First Name"] = elections["Candidate"].str.split().str[0]

# %% [markdown]
# `join` in pandas

# %%
#Merge both elections and babynames and report your analysis
merged = pd.merge(left = elections, right = baby, left_on = "First Name", right_on = "Name")
merged.head(3)
# Out:
#    Year_x       Candidate                  Party  Popular vote Result  \
# 0    1824  Andrew Jackson  Democratic-Republican        151271   loss
# 1    1824  Andrew Jackson  Democratic-Republican        151271   loss
# 2    1824  Andrew Jackson  Democratic-Republican        151271   loss
#
#            % First Name State Sex  Year_y    Name  Count
# 0  57.210122     Andrew    CA   F    1963  Andrew      5
# 1  57.210122     Andrew    CA   F    1968  Andrew      7
# 2  57.210122     Andrew    CA   F    1970  Andrew      5

# %%
# Sort using Count
merged.sort_values(by="Count",inplace=True)

merged
# Out:
#        Year_x         Candidate                  Party  Popular vote Result  \
# 0        1824    Andrew Jackson  Democratic-Republican        151271   loss
# 8596     1856  Millard Fillmore               American        873053   loss
# 8588     1856  Millard Fillmore               American        873053   loss
# 8586     1856  Millard Fillmore               American        873053   loss
# 8584     1856  Millard Fillmore               American        873053   loss
# ...       ...               ...                    ...           ...    ...
# 18344    1988   Michael Dukakis             Democratic      41809074   loss
# 18527    2004  Michael Badnarik            Libertarian        397265   loss
# 18345    1988   Michael Dukakis             Democratic      41809074   loss
# 18711    2004  Michael Peroutka           Constitution        143630   loss
# 18528    2004  Michael Badnarik            Libertarian        397265   loss
#
#                % First Name State Sex  Year_y     Name  Count
# 0      57.210122     Andrew    CA   F    1963   Andrew      5
# 8596   21.554001    Millard    CA   M    1951  Millard      5
# 8588   21.554001    Millard    CA   M    1938  Millard      5
# 8586   21.554001    Millard    CA   M    1936  Millard      5
# 8584   21.554001    Millard    CA   M    1931  Millard      5
# ...          ...        ...   ...  ..     ...      ...    ...
# 18344  45.770691    Michael    CA   M    1956  Michael   8258
# 18527   0.325108    Michael    CA   M    1956  Michael   8258
# 18345  45.770691    Michael    CA   M    1957  Michael   8260
# 18711   0.117542    Michael    CA   M    1957  Michael   8260
# 18528   0.325108    Michael    CA   M    1957  Michael   8260
#
# [21938 rows x 12 columns]
